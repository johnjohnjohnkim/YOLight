# %%
# !nvidia-smi
# Out:
# Wed Jul  8 13:35:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.79                 Driver Version: 595.79         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5070 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   38C    P8             27W /  300W |    1750MiB /  16303MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1672    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            2012    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A            2032    C+G   ...UI3Apps\PowerToys.Peek.UI.exe      N/A      |
# |    0   N/A  N/A            4020    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A            6088    C+G   ....0.4022.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            6312    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            7040    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           10388    C+G   ...a\Roaming\Spotify\Spotify.exe      N/A      |
# |    0   N/A  N/A           10424    C+G   ...s\Win64\EpicGamesLauncher.exe      N/A      |
# |    0   N/A  N/A           11488    C+G   ...s\PowerToys.ColorPickerUI.exe      N/A      |
# |    0   N/A  N/A           13232    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           13528    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           13648    C+G   ....0.4022.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           13900    C+G   ...Local\PowerToys\PowerToys.exe      N/A      |
# |    0   N/A  N/A           14824    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           15680    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           16572    C+G   ...al\Programs\Notion\Notion.exe      N/A      |
# |    0   N/A  N/A           17620    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           18864    C+G   ...Next\CNext\RadeonSoftware.exe      N/A      |
# |    0   N/A  N/A           20012    C+G   ...aries\Win64\EpicWebHelper.exe      N/A      |
# |    0   N/A  N/A           20352    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           22608    C+G   ...Toys\PowerToys.FancyZones.exe      N/A      |
# |    0   N/A  N/A           22784    C+G   ...s\PowerToys.AdvancedPaste.exe      N/A      |
# |    0   N/A  N/A           29008    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           29956    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           31308    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           31376    C+G   ...8bbwe\Microsoft.CmdPal.UI.exe      N/A      |
# |    0   N/A  N/A           34672    C+G   ...lpaper_engine\wallpaper64.exe      N/A      |
# |    0   N/A  N/A           35940    C+G   ....0.4022.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           36376    C+G   ...D\CNext\CNext\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           37140    C+G   ...lus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A           38780    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           39576    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in .\venv\Lib\site-packages (8.4.78)
# Requirement already satisfied: numpy>=1.23.0 in .\venv\Lib\site-packages (from ultralytics) (2.5.0)
# Requirement already satisfied: matplotlib>=3.3.0 in .\venv\Lib\site-packages (from ultralytics) (3.11.0)
# Requirement already satisfied: opencv-python>=4.6.0 in .\venv\Lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in .\venv\Lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in .\venv\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in .\venv\Lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in .\venv\Lib\site-packages (from ultralytics) (2.12.1+cu132)
# Requirement already satisfied: torchvision>=0.9.0 in .\venv\Lib\site-packages (from ultralytics) (0.27.1+cu132)
# Requirement already satisfied: psutil>=5.8.0 in .\venv\Lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in .\venv\Lib\site-packages (from ultralytics) (1.42.0)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in .\venv\Lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in .\venv\Lib\site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.42.0 in .\venv\Lib\site-packages (from polars>=0.20.0->ultralytics) (1.42.0)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !yolo task=detect mode = train model=yolov8s.pt data={dataset.location}/data.yml epochs=20 imgsz=640
